# %% [markdown]
# # Welcome to elvita's Jupyter Book
# ##NIM: 230411100128
#
# ini adalah Jupiter Book Elvita yang berisi tentang Materi Komputasi Aljabar Linier Semester 2
#
# semoga materi ini bermanfaat bagi pembaca.
#
# This is a small sample book to give you a feel for how book content is
# structured.
# kunjungi link berikut untuk dokumen Jupiter Notebook [the Jupyter Book documentation](https://jupyterbook.org) untuk informasi lebih lanjut.
#
# Check out the content pages bundled with this sample book to see more.
#
# ```{tableofcontents}
# ```
